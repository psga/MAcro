# %% [markdown]
# ![logo_MeIA.png](data:image/png;base64,...)

# %% [markdown]
# # Cálculo
#
# VALERIA RULLONI

# %% [markdown]
# Temas abordados en la notebook:
#
# ● Funciones de una variable real.
#
# ● Funciones trigonométricas, exponencial y logarítmica. Función inversa. El
# concepto de continuidad.
#
# ● Cociente incremental. Derivada de una función de una variable real en un punto. Interpretación geométrica.
#
# ● Extremos y puntos de inflexión.
#
# ● Integrales.
#
# ● Varias variables. Derivadas parciales.

# %%
#primero importamos las librerías de python necesarias
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Funciones
#
# **Funciones de una Variable real:**
#
# $ x \rightarrow f(x)$
#
# donde $x\in \mathbb{R}$   o   donde $x\in [a.b]$, es decir con  $a\leq x \leq b$
#
# o   donde $x\in [a.b)$, es decir con  $a\leq x < b$

# %% [markdown]
# supongamos  $-20\leq x < 20$

# %%
#generamos un vector con valores de x en [a,b)= [-20,20) ,
#no podemos tomar toooodos los valores como si fuera continuo,
#tomemos los más posibles por ej n=100 o n=10000
n=1000 # cantidad de muestras
a=-20 #inicio
b=20
x=np.linspace(a,b,n, endpoint=False)
print(x)
print('cantidad de muestras de x:',n)
# Out:
# [-20.   -19.96 -19.92 -19.88 -19.84 -19.8  -19.76 -19.72 -19.68 -19.64
#  -19.6  -19.56 -19.52 -19.48 -19.44 -19.4  -19.36 -19.32 -19.28 -19.24
#  -19.2  -19.16 -19.12 -19.08 -19.04 -19.   -18.96 -18.92 -18.88 -18.84
#  -18.8  -18.76 -18.72 -18.68 -18.64 -18.6  -18.56 -18.52 -18.48 -18.44
#  -18.4  -18.36 -18.32 -18.28 -18.24 -18.2  -18.16 -18.12 -18.08 -18.04
#  -18.   -17.96 -17.92 -17.88 -17.84 -17.8  -17.76 -17.72 -17.68 -17.64
#  -17.6  -17.56 -17.52 -17.48 -17.44 -17.4  -17.36 -17.32 -17.28 -17.24
#  -17.2  -17.16 -17.12 -17.08 -17.04 -17.   -16.96 -16.92 -16.88 -16.84
#  -16.8  -16.76 -16.72 -16.68 -16.64 -16.6  -16.56 -16.52 -16.48 -16.44
#  -16.4  -16.36 -16.32 -16.28 -16.24 -16.2  -16.16 -16.12 -16.08 -16.04
#  -16.   -15.96 -15.92 -15.88 -15.84 -15.8  -15.76 -15.72 -15.68 -15.64
#  -15.6  -15.56 -15.52 -15.48 -15.44 -15.4  -15.36 -15.32 -15.28 -15.24
#  -15.2  -15.16 -15.12 -15.08 -15.04 -15.   -14.96 -14.92 -14.88 -14.84
# ...

# %% [markdown]
# ## Funciones trigonométricas
#
# $f(x)= sen(x)$
#
# está definida para   $-\infty <x < \infty$
#
# la grafiquemos para $-20\leq x < 20$

# %%
f=np.sin(x) # vector, contiene la función evaluada p/c valor de x
print(len(f)) # vector de la misma longitud que x,
print(f)

# %%
#Visualizamos
plt.figure(figsize=(16,5))
plt.stem(x,f, label='sen(x)')
plt.xlabel('x (muestreado)')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Si queremos tomar más muestras cambiamos el n por 10000 por ejemplo
# Ej: probamos...

# %%
#Visualizamos con plot
plt.figure(figsize=(16,5))
plt.plot(x,f, label='sen(x)')
plt.xlabel('x (muestreado)')
plt.ylabel('f(x)=sen(x)')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# De ahora en más se usará plot (y no stem) pero entendiendo que siempre estamos considerando muestras (tantas como queramos) de una función definida en $ \mathbb{R}$  o un intervalo (continuo) de $ \mathbb{R}$

# %% [markdown]
# Consideremos otra función
# $g(x)=5 x-10$ está definida para   $-\infty <x < \infty$
#
# la grafiquemos para $-15\leq x < 15$

# %%
#definimos nuevamente x  y g para cada valor de x
n=500 # cantidad de muestras
a=-15 #inicio
b=15
x=np.linspace(a,b,n, endpoint=False)
g=5*x-10 #
h=6*x-10

# %%
#Visualizamos con plot
plt.figure(figsize=(16,5))
plt.plot(x,g, label='$g(x)=5 x-10$')
plt.plot(x,h, label='$h(x)=6*x-10$')
plt.xlabel('x (muestreado)')
plt.ylabel('g(x)=5 x-10$')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# Ejercicio: Agregar otra función $h(x)$ a la gráfica.

# %% [markdown]
# # Función inversa
# * Función exponencial y logarítmica.
# * El concepto de continuidad.

# %% [markdown]
# ## Función exponencial

# %% [markdown]
# Consideremos la función exponencial
# $e(x)=e^x$ está definida para   $-\infty <x < \infty$
#
# la grafiquemos para $-4\leq x < 4$

# %%
#definimos nuevamente x  y g para cada valor de x
n=500 # cantidad de muestras
a=-4 #inicio
b=4
x=np.linspace(a,b,n, endpoint=False)
e_x=np.exp(x) #

# %%
#Visualizamos con plot
#plt.figure(figsize=(16,5))
plt.plot(x,e_x, label='$y=e(x)=e^x$')
plt.xlabel('x (muestreado)')
plt.ylabel('$y=e(x)=e^x$')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Función inversa: ej. log
# $f(x)=y ⇔ f^{-1}(y)=x$
#
# Por ejemplo:
# si $f(x)=e^x ⇔ f^{-1}(y)=log(y)=x$
#
# notar que en este caso $y=e^x$ solo toma valores positivos, entonces $log(y)$ está definida para $0<y<\infty$.

# %%
#definimos y
n=500 # cantidad de muestras
a=0.01 #inicio
b=50
y=np.linspace(a,b,n, endpoint=False)
e_1=np.log(y) #definimos f⁻1 (y)

# %%
plt.figure(figsize=(16,10))
plt.subplot(211)
plt.plot(x,e_x, label='$y=e(x)=e^x$')
plt.xlabel('x (muestreado)')
plt.ylabel('$y=e(x)=e^x$')
plt.grid()
plt.legend()
plt.subplot(212)
plt.plot(y,e_1, label='log(y)')
plt.xlabel('y (muestreado)')
plt.ylabel('$f^{-1}(y)=log(y)$')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Funciones de enlace
#
# Se usan en aprendizaje automatico profundo (deep learning <-> redes neuronales)

# %% [markdown]
# ### Relu
# Consideremos la función de enlace Relu
# $f(x)=max(0,x)$ está definida para   $-\infty <x < \infty$
#
# la grafiquemos para $-4\leq x < 4$

# %%
#definimos nuevamente x  y la función para cada valor de x
n=500 # cantidad de muestras
a=-4 #inicio
b=4
x=np.linspace(a,b,n, endpoint=False)
r_x=np.maximum(0,x) #

# %%
#Visualizamos con plot
plt.figure(figsize=(16,5))
plt.plot(x,r_x, label='$f(x)=max(0,x)$')
plt.xlabel('x (muestreado)')
plt.ylabel('$f(x)=max(0,x)$')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Sigmoide
# Consideremos la función de enlace que se deriva de la exponencial
# $f(x)=\frac{1}{1+e^{-x}}$ está definida para   $-\infty <x < \infty$
#
# la grafiquemos para $-4\leq x < 4$

# %%
#definimos nuevamente x  y g para cada valor de x
n=500 # cantidad de muestras
a=-4 #inicio
b=4
x=np.linspace(a,b,n, endpoint=False)
l_x=np.exp(x)/(1+np.exp(x)) #

# %%
#Visualizamos con plot
plt.figure(figsize=(16,5))
plt.plot(x,l_x, label='$f(x)=1/(1+e^{-x})$')
plt.xlabel('x (muestreado)')
plt.ylabel('$f(x)=1/(1+e^{-x})$')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### tanh
# Tangente hiperbolica. Esta la función de enlace tambien se deriva de la exponencial
# $f(x)=\frac{2}{1+e^{-2x}}-1$ está definida para   $-\infty <x < \infty$
#
# la grafiquemos para $-4\leq x < 4$

# %%
#definimos nuevamente x  y g para cada valor de x
n=500 # cantidad de muestras
a=-4 #inicio
b=4
x=np.linspace(a,b,n, endpoint=False)
th_x=np.tanh(x) #

# %%
#Visualizamos con plot
plt.figure(figsize=(16,5))
plt.plot(x,th_x, label='$f(x)=2/(1+e^{-2x})-1$')
plt.xlabel('x (muestreado)')
plt.ylabel('$f(x)=2/(1+e^{-2x})-1$')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Derivada e integral
#
# ● Cociente incremental. Derivada de una función de una variable real en un punto. Interpretación geométrica.
#
# ● Extremos y puntos de inflexión. Concavidad y convexidad.
#
# ● Integrales.

# %% [markdown]
# ![difference_between_derivative_and_integral.png](data:image/png;base64,...)

# %% [markdown]
#  [fuente:](http://hyperphysics.phy-astr.gsu.edu/hbasees/Math/derint.html)

# %% [markdown]
# Si $f(x)= sen(x)$
#
# la derivada de $f$ es
#
# $f'(x)=\frac{f(x)}{dx}= cos(x)$ .Las grafiquemos para $-\pi\leq x < \pi$

# %%
n=400 # cantidad de muestras
(a,b)=(-np.pi ,np.pi)
x=np.linspace(a,b,n, endpoint=False)
f=np.sin(x) # vector, contiene la función evaluada p/c valor de x
f_1=np.cos(x)

# %%
#Visualizamos con plot y subplot
plt.figure(figsize=(16,10))
plt.subplot(211)
plt.plot(x,f, label='sen(x)')
plt.xlabel('x (muestreado)')
plt.ylabel('f(x)=sen(x)')
plt.grid()
plt.axvline(-np.pi/2, color = "red", linewidth = 1, linestyle = "dashed")
plt.axvline(0, color = "red", linewidth = 1, linestyle = "dashed");
plt.axvline(np.pi/2, color = "red", linewidth = 1, linestyle = "dashed");
plt.legend()
plt.subplot(212)
plt.plot(x,f_1, label='cos(x)')
plt.xlabel('x (muestreado)')
plt.ylabel('$f^{-1}(x)=cos(x)$')
plt.grid()
plt.axvline(-np.pi/2, color = "red", linewidth = 1, linestyle = "dashed")
plt.axvline(0, color = "red", linewidth = 1, linestyle = "dashed");
plt.axvline(np.pi/2, color = "red", linewidth = 1, linestyle = "dashed");
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# Si $f(x)= x^2$
#
# la derivada de $f$ es
#
# $f'(x)=\frac{d f(x)}{dx}= 2x$ .
#
# la primitiva (integral indefinida) de $f$ es
#
# $g(x)=\frac{1}{3}x^3$, tal que $g'(x)=f(x)$.
#
#
# Las grafiquemos para $-2\leq x < 2$

# %%
n=400 # cantidad de muestras
(a,b)=(-3 ,3)
x=np.linspace(a,b,n, endpoint=False)
f=x**2 # vector, contiene la función evaluada p/c valor de x
df=2*x #derivada de f
af=x**3/3 #integral (area bajola curva) de f

# %%
#Visualizamos con plot y subplot
plt.figure(figsize=(16,10))
plt.subplot(311)
plt.plot(x,f, label='x^2')
plt.xlabel('x ')
plt.ylabel('$f(x)=x^2$')
plt.grid()
plt.legend()

plt.subplot(312)
plt.plot(x,df, label='derivada de f=2x')
plt.xlabel('x')
plt.ylabel('derivada de f=2x')
plt.grid()
plt.axvline(0, color = "red", linewidth = 1, linestyle = "dashed");
plt.legend()

plt.subplot(313)
plt.plot(x,af, label='integral de f: $x^3/3$')
plt.xlabel('x')
plt.ylabel('integral de f: $x^3/3$')
plt.grid()
plt.axvline(0, color = "red", linewidth = 1, linestyle = "dashed");
plt.legend()

plt.show()

# %% [markdown]
# Filminas Cálculo en Varias variables

# %% [markdown]
# #  Varias variables.
#
# * Varias variables. Derivadas parciales.
#
# $f(x,y)$ con $x$ e $y$ números reales
#
# Por ejemplo:
#
# $f(x,y)=sen(x).cos(y)$
#
# Las derivadas parciales de f son:
#
# $\frac{\partial f(x,y)}{\partial x}= cos(x).cos(y)$ .
#
# $\frac{\partial f(x,y)}{\partial y}= - sen(x).sen(y)$ .

# %%
n=400
(a,b)=(-np.pi ,np.pi)
x=np.linspace(a,b,n, endpoint=False)
y=np.linspace(a,b,n, endpoint=False)
f=np.zeros((n,n))
for i in range(n):
  f[i]= np.sin(x[i])*np.cos(y)

# %%
#gráfico 3D
from mpl_toolkits.mplot3d import axes3d
# Creamos la figura
fig = plt.figure()
# Creamos el plano 3D
ax1 = fig.add_subplot(111, projection='3d')
#discretizamos en k=5 a x para (k pueden ser más o menos) un color para cada x
k=50
paso=n//k
for i in range(k):
  xn=np.full(n,x[8*i])
  ax1.plot3D(xn,y,f[8*i], label='x='+str(x[8*i]))
plt.show()

# %%
plt.figure(figsize=(16,10))
plt.pcolormesh(x,y,f)
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.show()
